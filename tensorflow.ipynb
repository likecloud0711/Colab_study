# %%
import tensorflow as tf

print(tf.__version__)
a=tf.random.uniform([2,3],0,1)
print(a)
print(type(a))
# Out:
# 2.9.2
# tf.Tensor(
# [[0.209396   0.02122462 0.6600177 ]
#  [0.9918692  0.59816015 0.17988217]], shape=(2, 3), dtype=float32)
# <class 'tensorflow.python.framework.ops.EagerTensor'>
